# %% [markdown]
# # Q2

# %% [markdown]
# *   In this question we will Build a bigram HMM tagger.
# *   First we split the part-of-speech-tagged corpus into a training set and test set.
# *   From the labeled training set, we train the transition and observation probabilities of the HMM tagger directly on the hand-tagged data.
# *   Then implement the Viterbi algorithm so we can decode a test sentence.
# *   Run the algorithm on the test set. Report its error rate and
# compare its performance to the most frequent tag baseline.
# *   Build a confusion matrix and investigate the most frequent errors.

# %%
import nltk
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# True

# %%
import math
import nltk
nltk.download('brown')
from nltk.corpus import brown
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.

# %%
import numpy as np
import math

# %%
def collect_probabilities(_samples):
    """
    Collects various probabilities and frequencies required for Hidden Markov Model (HMM) training based on given samples.

    Args:
    _samples (list): A list of tuples containing (word, tag) pairs representing training data.

    Returns:
    tuple: A tuple containing four dictionaries:
           - tag_freq: A dictionary storing the frequency of each tag type.
           - word_per_tag_freq: A nested dictionary storing the frequency of each word under each tag.
           - bigram: A nested dictionary representing the bigram probabilities between tag types.
           - pi: A dictionary storing the initial probability distributions for tag types.

    Comments:
    - tag_freq: Stores the frequency of each tag type observed in the training data.
    - word_per_tag_freq: Stores the frequency of each word observed under each tag in the training data.
      - Each word under a specific tag is initialized with a count of 2 to provide initial smoothing.
    - bigram: Represents the transition probabilities between tag types based on bigram counts.
    - pi: Stores the initial probability distributions for tag types based on the second tag in each sample.
    """
    tag_freq = {}
    word_per_tag_freq = {}
    bigram = {}
    pi = {}
    samples_len = len(_samples)

    # Iterate through samples to collect tag frequencies, word frequencies under each tag, and initial probabilities
    for i in range(samples_len):
        sample = _samples[i]
        has_next = i + 1 < samples_len

        # Collect data for initial probabilities (pi)
        if has_next:
            if _samples[i + 1][1] not in pi:
                pi.update({_samples[i + 1][1]: 2})
            else:
               pi[_samples[i + 1][1]] += 1

        # Count tag frequencies (tag_freq) and word frequencies under each tag (word_per_tag_freq)
        if sample[1] not in tag_freq:
            tag_freq.update({sample[1]: 2})
            word_per_tag_freq.update({sample[1]: {sample[0]: 2}})
        else:
            tag_freq[sample[1]] += 1
            if sample[0] not in word_per_tag_freq[sample[1]]:
                word_per_tag_freq[sample[1]].update({sample[0]: 2})
            else:
                word_per_tag_freq[sample[1]][sample[0]] += 1


    # Initialize the bigram matrix with default counts
    for tag_0 in tag_freq:
        bigram.update({tag_0: {}})
        for tag_1 in tag_freq:
            bigram[tag_0].update({tag_1: 1})

    # Count bigram occurrences
    for i in range(samples_len):
        if (i+1) < samples_len:
        # Your code here
            _, tag_i = _samples[i]
            _, tag_next = _samples[i+1]
            bigram[tag_i][tag_next] += 1

    # Return collected probabilities and frequencies
    return tag_freq, word_per_tag_freq, bigram, pi

# %%
_samples = [('apple', 'fruit'), ('banana', 'fruit'), ('apple', 'fruit'), ('apple', 'color'), ('banana', 'color')]
_dict_generated = collect_probabilities(_samples)
_dict_generated
# Out:
# ({'fruit': 4, 'color': 3},
#  {'fruit': {'apple': 3, 'banana': 2}, 'color': {'apple': 2, 'banana': 2}},
#  {'fruit': {'fruit': 3, 'color': 2}, 'color': {'fruit': 1, 'color': 2}},
#  {'fruit': 3, 'color': 3})

# %%
def create_confusion_matrix(predictions, hidden_state, confusion_matrices , is_correct):
    """
    Updates the confusion matrices based on the predictions and hidden states,
    calculates the number of correct predictions, and identifies tags with
    the most false positives and false negatives.

    Args:
    predictions (list): Predicted sequence of tags for the given input data.
    hidden_state (list): Actual sequence of tags for the given input data.
    confusion_matrices (dict): A dictionary containing confusion matrices for each tag.
    is_correct (int): Counter for the number of correct predictions.

    Returns:
    int: Updated count of correct predictions after processing the input data.

    Comments:
    - As the Viterbi algorithm processes each sentence in the test data,
      it compares the predicted tags against the actual tags for each word in the sentence.
        - For each word in the sentence, if the predicted tag matches the actual tag (a true positive),
          the corresponding count in the confusion matrix for that tag is incremented.
        - If the predicted tag does not match the actual tag:
            - If the predicted tag is incorrect (a false positive), the FP count for
              the predicted tag is incremented, and the TN counts for other tags are incremented.
            - If the actual tag is not predicted (a false negative), the FN count for the actual
              tag is incremented, and the TN counts for other tags are incremented.
    - After updating the confusion matrices, the function identifies tags with
      the highest counts of false positives and false negatives.
    """
    # fill in the confusion matrix
    for i in range(len(predictions)):
        if predictions[i] == hidden_state[i]:
            # prediction is correct
            is_correct += 1
            for tag in confusion_matrices:
                if tag == predictions[i]:
                    confusion_matrices[tag]['TP'] += 1
                else:
                    confusion_matrices[tag]['TN'] += 1
        else:
            # prediction is incorrect
            for tag in confusion_matrices:
                # Your code here
                if tag == predictions[i]:
                    confusion_matrices[tag]['FP'] += 1
                if tag == hidden_state[i]:
                    confusion_matrices[tag]['FN'] += 1
                else:
                    confusion_matrices[tag]['TN'] += 1

    # rank
    highest_FP_tag = []
    highest_FP = -1
    highest_FN_tag = []
    highest_FN = -1

    for tag in confusion_matrices:

        print(f'{tag}: {confusion_matrices[tag]}')

        if confusion_matrices[tag]['FP'] > highest_FP:
            highest_FP = confusion_matrices[tag]['FP']
            highest_FP_tag = tag

        if confusion_matrices[tag]['FN'] > highest_FN:
            highest_FN = confusion_matrices[tag]['FN']
            highest_FN_tag = tag

    print(f'\nTag with the most false positives is: {highest_FP_tag} with {highest_FP} counts.')
    print(f'Tag with the most false negative is:  {highest_FN_tag} with {highest_FN} counts.')

    return is_correct

# %%
def viterbi(_samples, _tag_freq, _word_per_tag_freq, _bigram, _init_dist):
    """
    Performs the Viterbi algorithm for part-of-speech tagging on a given test set of sentences.

    Args:
    _samples (list): A list of tuples containing (word, tag) pairs representing the test data.
    _tag_freq (dict): A dictionary storing the frequency of each tag type observed in the training data.
    _word_per_tag_freq (dict): A nested dictionary storing the frequency of each word observed under each tag in the training data.
    _bigram (dict): A nested dictionary representing the bigram probabilities between tag types.
    _init_dist (dict): A dictionary storing the initial probability distributions for tag types.

    Comments:
    - This function implements the Viterbi algorithm for part-of-speech tagging.
    - It processes each sentence in the test set, using '.' as an indicator that a sentence is over.
    - The function populates a confusion matrix to track the performance of the model.
    - The Viterbi algorithm is used to find the most likely sequence of tags for each sentence.
    - The algorithm iterates through each word in the sentence, calculating the most likely tag sequence based on probabilities and transition probabilities.
    - The model's predictions are compared against the actual tags to evaluate accuracy and populate the confusion matrix.
    - The function prints detailed information about predictions, including the sentence, hidden states, and predicted tags.
    - It also identifies tags with the most false positives and false negatives based on the confusion matrix.
    - Finally, the function prints the overall accuracy of the model on the test set.
    """
    test_size = len(_samples)
    current_index = 0
    is_correct = 0

    # populate the confusion matrix
    confusion_matrices = {}
    for tag in _tag_freq:
        confusion_matrices.update({tag: {'TP': 0, 'FP': 0, 'TN': 0, 'FN': 0}})

    while current_index < test_size:
        # find the boundry of a sentence
        sentence = []
        hidden_state = []
        last_token = ''
        while last_token != '.' and current_index < test_size:
            sentence.append(_samples[current_index][0])
            hidden_state.append(_samples[current_index][1])
            last_token = sentence[-1]
            current_index += 1

        # initialization step
        path_probability = {}
        backpointer = {}
        for tag in init_dist:
            path_probability.update({tag: []})
            backpointer.update({tag: [0]})

            # initial distribution of this tag
            pi_tag = init_dist[tag]

            # b_word is the probability of the word being generated by this tag
            if sentence[0] in _word_per_tag_freq[tag]:
                b_word = _word_per_tag_freq[tag][sentence[0]]
            else:
                b_word = 2.2250738585072014e-100
            path_probability[tag].append(math.log(pi_tag * b_word, 10))

        # recursion step
        T = len(sentence)
        for i in range(1, T):
            for tag in init_dist:

                if sentence[i] in _word_per_tag_freq[tag]:
                    b_word = _word_per_tag_freq[tag][sentence[i]]
                else:
                    b_word = 2.2250738585072014e-100
                b_word = math.log(b_word, 10)

                # search the maximum value of
                # viterbi[s', t-1] * a(s|s') *b_s(o_t)
                best_trans_prob = -2.2250738585072014e+308
                best_trans_tag = ''
                for prev_tag in init_dist:
                    if prev_tag in _bigram and tag in _bigram[prev_tag]:
                        transitional_prob = _bigram[prev_tag][tag]
                    else:
                        transitional_prob = 2.2250738585072014e-100

                    transitional_prob = math.log(transitional_prob, 10)

                    prob = path_probability[prev_tag][i - 1] + transitional_prob + b_word

                    if prob > best_trans_prob:
                        best_trans_prob = prob
                        best_trans_tag = prev_tag

                path_probability[tag].append(best_trans_prob)
                backpointer[tag].append(best_trans_tag)

        # termination step
        best_path_prob = -2.2250738585072014e+308
        best_path_pointer = None
        for tag in init_dist:
            # Your code here
            prob = path_probability[tag][T - 1]
            if prob > best_path_prob:
                best_path_prob = prob
                best_path_pointer = tag

        predictions = [best_path_pointer]

        # make the predictions path
        for i in reversed(range(1, T)):
            # Your code here
            best_path_pointer = backpointer[best_path_pointer][i]
            predictions.append(best_path_pointer)

        predictions.reverse()

        print(f'sentence:       {sentence}')
        print(f'hidden s:       {hidden_state}')
        print(f'predictions:    {predictions}')

        is_correct = create_confusion_matrix(predictions, hidden_state, confusion_matrices, is_correct)

    print(f'\nmodel got {is_correct} samples correct out of {test_size}')
    print(f'accuracy: {is_correct / test_size}')

# %%
CORPUS = brown.tagged_words(categories='news', tagset='universal')
CORPUS_SIZE = len(brown.tagged_words(categories='news'))

CUT_OFF = math.floor(CORPUS_SIZE * 0.75)

# section off training and testing lists from corpus
training_list = CORPUS[:CUT_OFF]
testing_list = CORPUS[CUT_OFF:]

tag_frequency, word_per_tag_frequency, tag_bigram, init_dist = collect_probabilities(training_list)
viterbi(testing_list, tag_frequency, word_per_tag_frequency, tag_bigram, init_dist)
# Out:
# Streaming output truncated to the last 5000 lines.
# ADP: {'TP': 2309, 'FP': 469, 'TN': 16424, 'FN': 26}
# .: {'TP': 2272, 'FP': 13, 'TN': 16487, 'FN': 0}
# ADV: {'TP': 583, 'FP': 16, 'TN': 17926, 'FN': 250}
# CONJ: {'TP': 556, 'FP': 2, 'TN': 18187, 'FN': 16}
# PRT: {'TP': 218, 'FP': 8, 'TN': 18271, 'FN': 270}
# PRON: {'TP': 498, 'FP': 2, 'TN': 18228, 'FN': 33}
# NUM: {'TP': 256, 'FP': 0, 'TN': 18400, 'FN': 103}
# X: {'TP': 4, 'FP': 0, 'TN': 18724, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1132 counts.
# Tag with the most false negative is:  ADJ with 589 counts.
# sentence:       ['Crime', ':', "'", 'skyjacked', "'", 'From', 'International', 'Airport', 'in', 'Los', 'Angeles', 'to', 'International', 'Airport', 'in', 'Houston', ',', 'as', 'the', 'great', 'four-jet', 'Boeing', '707', 'flies', ',', 'is', 'a', 'routine', 'five', 'hours', 'and', '25', 'minutes', ',', 'including', 'stopovers', 'at', 'Phoenix', ',', 'El', 'Paso', ',', 'and', 'San', 'Antonio', '.']
# hidden s:       ['NOUN', '.', '.', 'VERB', '.', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'NUM', 'VERB', '.', 'VERB', 'DET', 'ADJ', 'NUM', 'NOUN', 'CONJ', 'NUM', 'NOUN', '.', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.']
# predictions:    ['NOUN', '.', '.', 'NOUN', '.', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'NOUN', '.', 'VERB', 'DET', 'NOUN', 'NUM', 'NOUN', 'CONJ', 'NUM', 'NOUN', '.', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2259, 'FP': 184, 'TN': 16523, 'FN': 23}
# NOUN: {'TP': 4698, 'FP': 1137, 'TN': 13961, 'FN': 146}
# ADJ: {'TP': 954, 'FP': 89, 'TN': 17260, 'FN': 591}
# VERB: {'TP': 2158, 'FP': 100, 'TN': 16117, 'FN': 530}
# ADP: {'TP': 2316, 'FP': 469, 'TN': 16463, 'FN': 26}
# .: {'TP': 2281, 'FP': 13, 'TN': 16524, 'FN': 0}
# ADV: {'TP': 583, 'FP': 16, 'TN': 17972, 'FN': 250}
# CONJ: {'TP': 558, 'FP': 2, 'TN': 18231, 'FN': 16}
# PRT: {'TP': 218, 'FP': 8, 'TN': 18317, 'FN': 270}
# PRON: {'TP': 498, 'FP': 2, 'TN': 18274, 'FN': 33}
# NUM: {'TP': 258, 'FP': 0, 'TN': 18443, 'FN': 104}
# X: {'TP': 4, 'FP': 0, 'TN': 18770, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1137 counts.
# Tag with the most false negative is:  ADJ with 591 counts.
# sentence:       ['When', 'Continental', 'Airlines', 'night-coach', 'Flight', '54', 'took', 'off', 'at', '11:30', 'one', 'night', 'last', 'week', ',', 'there', 'was', 'no', 'reason', 'to', 'think', 'it', 'would', 'take', 'any', 'longer', '.']
# hidden s:       ['ADV', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'NUM', 'VERB', 'PRT', 'ADP', 'NUM', 'NUM', 'NOUN', 'ADJ', 'NOUN', '.', 'PRT', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'PRON', 'VERB', 'VERB', 'DET', 'ADJ', '.']
# predictions:    ['ADV', 'ADJ', 'NOUN', 'NOUN', 'ADP', 'NUM', 'VERB', 'ADP', 'ADP', 'NUM', 'NOUN', 'NOUN', 'NOUN', 'NOUN', '.', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'VERB', 'PRON', 'VERB', 'VERB', 'DET', 'ADV', '.']
# DET: {'TP': 2261, 'FP': 184, 'TN': 16548, 'FN': 23}
# NOUN: {'TP': 4703, 'FP': 1139, 'TN': 13982, 'FN': 147}
# ADJ: {'TP': 955, 'FP': 89, 'TN': 17284, 'FN': 593}
# VERB: {'TP': 2163, 'FP': 100, 'TN': 16139, 'FN': 530}
# ADP: {'TP': 2317, 'FP': 472, 'TN': 16489, 'FN': 26}
# .: {'TP': 2283, 'FP': 13, 'TN': 16549, 'FN': 0}
# ADV: {'TP': 584, 'FP': 17, 'TN': 17998, 'FN': 250}
# CONJ: {'TP': 558, 'FP': 2, 'TN': 18258, 'FN': 16}
# PRT: {'TP': 219, 'FP': 8, 'TN': 18341, 'FN': 272}
# PRON: {'TP': 499, 'FP': 2, 'TN': 18300, 'FN': 33}
# NUM: {'TP': 260, 'FP': 0, 'TN': 18467, 'FN': 105}
# X: {'TP': 4, 'FP': 0, 'TN': 18797, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1139 counts.
# Tag with the most false negative is:  ADJ with 593 counts.
# sentence:       ['The', 'plane', 'put', 'down', 'on', 'schedule', 'at', '1:35', 'a.m.', 'in', 'Phoenix', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'PRT', 'ADP', 'NOUN', 'ADP', 'NUM', 'ADV', 'ADP', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'VERB', 'PRT', 'ADP', 'NOUN', 'ADP', 'NOUN', 'ADV', 'ADP', 'NOUN', '.']
# DET: {'TP': 2262, 'FP': 184, 'TN': 16559, 'FN': 23}
# NOUN: {'TP': 4706, 'FP': 1140, 'TN': 13991, 'FN': 147}
# ADJ: {'TP': 955, 'FP': 89, 'TN': 17296, 'FN': 593}
# VERB: {'TP': 2164, 'FP': 100, 'TN': 16150, 'FN': 530}
# ADP: {'TP': 2320, 'FP': 472, 'TN': 16498, 'FN': 26}
# .: {'TP': 2284, 'FP': 13, 'TN': 16560, 'FN': 0}
# ADV: {'TP': 585, 'FP': 17, 'TN': 18009, 'FN': 250}
# CONJ: {'TP': 558, 'FP': 2, 'TN': 18270, 'FN': 16}
# PRT: {'TP': 220, 'FP': 8, 'TN': 18352, 'FN': 272}
# PRON: {'TP': 499, 'FP': 2, 'TN': 18312, 'FN': 33}
# NUM: {'TP': 260, 'FP': 0, 'TN': 18478, 'FN': 106}
# X: {'TP': 4, 'FP': 0, 'TN': 18809, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1140 counts.
# Tag with the most false negative is:  ADJ with 593 counts.
# sentence:       ['Thirty-one', 'minutes', 'later', ',', 'when', 'it', 'took', 'off', 'for', 'El', 'Paso', ',', 'hardly', 'anyone', 'of', 'the', 'crew', 'of', 'six', 'or', 'the', '65', 'other', 'passengers', 'paid', 'any', 'attention', 'to', 'the', 'man', 'and', 'teen-age', 'boy', 'who', 'had', 'come', 'aboard', '.']
# hidden s:       ['NUM', 'NOUN', 'ADV', '.', 'ADV', 'PRON', 'VERB', 'PRT', 'ADP', 'NOUN', 'NOUN', '.', 'ADV', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'CONJ', 'DET', 'NUM', 'ADJ', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'ADJ', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADV', '.']
# predictions:    ['NOUN', 'NOUN', 'ADV', '.', 'ADV', 'PRON', 'VERB', 'ADP', 'ADP', 'NOUN', 'NOUN', '.', 'ADV', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'CONJ', 'DET', 'NUM', 'ADJ', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'NOUN', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADV', '.']
# DET: {'TP': 2266, 'FP': 184, 'TN': 16593, 'FN': 23}
# NOUN: {'TP': 4715, 'FP': 1142, 'TN': 14020, 'FN': 147}
# ADJ: {'TP': 956, 'FP': 89, 'TN': 17332, 'FN': 594}
# VERB: {'TP': 2168, 'FP': 100, 'TN': 16184, 'FN': 530}
# ADP: {'TP': 2324, 'FP': 473, 'TN': 16532, 'FN': 26}
# .: {'TP': 2287, 'FP': 13, 'TN': 16595, 'FN': 0}
# ADV: {'TP': 589, 'FP': 17, 'TN': 18043, 'FN': 250}
# CONJ: {'TP': 560, 'FP': 2, 'TN': 18306, 'FN': 16}
# PRT: {'TP': 220, 'FP': 8, 'TN': 18389, 'FN': 273}
# PRON: {'TP': 501, 'FP': 2, 'TN': 18348, 'FN': 33}
# NUM: {'TP': 262, 'FP': 0, 'TN': 18513, 'FN': 107}
# X: {'TP': 4, 'FP': 0, 'TN': 18847, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1142 counts.
# Tag with the most false negative is:  ADJ with 594 counts.
# sentence:       ['At', '3:57', 'a.m.', ',', 'with', 'the', 'plane', 'about', 'twenty', 'minutes', 'out', 'of', 'El', 'Paso', ',', 'passenger', 'Robert', 'Berry', ',', 'a', 'San', 'Antonio', 'advertising', 'man', ',', 'glanced', 'up', 'and', 'saw', 'the', 'man', 'and', 'boy', ',', 'accompanied', 'by', 'a', 'stewardess', ',', 'walking', 'up', 'the', 'aisle', 'toward', 'the', 'cockpit', '.']
# hidden s:       ['ADP', 'NUM', 'ADV', '.', 'ADP', 'DET', 'NOUN', 'ADV', 'NUM', 'NOUN', 'ADP', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'NOUN', 'VERB', 'NOUN', '.', 'VERB', 'PRT', 'CONJ', 'VERB', 'DET', 'NOUN', 'CONJ', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['ADP', 'NOUN', 'ADV', '.', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'NOUN', 'ADP', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'NOUN', 'NOUN', 'NOUN', '.', 'NOUN', 'ADP', 'CONJ', 'VERB', 'DET', 'NOUN', 'CONJ', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2272, 'FP': 184, 'TN': 16634, 'FN': 23}
# NOUN: {'TP': 4730, 'FP': 1145, 'TN': 14052, 'FN': 147}
# ADJ: {'TP': 956, 'FP': 89, 'TN': 17379, 'FN': 594}
# VERB: {'TP': 2171, 'FP': 100, 'TN': 16226, 'FN': 532}
# ADP: {'TP': 2331, 'FP': 475, 'TN': 16572, 'FN': 26}
# .: {'TP': 2294, 'FP': 13, 'TN': 16635, 'FN': 0}
# ADV: {'TP': 590, 'FP': 17, 'TN': 18088, 'FN': 251}
# CONJ: {'TP': 562, 'FP': 2, 'TN': 18351, 'FN': 16}
# PRT: {'TP': 220, 'FP': 8, 'TN': 18435, 'FN': 274}
# PRON: {'TP': 501, 'FP': 2, 'TN': 18395, 'FN': 33}
# NUM: {'TP': 263, 'FP': 0, 'TN': 18558, 'FN': 108}
# X: {'TP': 4, 'FP': 0, 'TN': 18894, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1145 counts.
# Tag with the most false negative is:  ADJ with 594 counts.
# sentence:       ['``', 'The', 'man', 'was', 'bent', 'over', 'with', 'his', 'hand', 'on', 'his', 'stomach', "''", ',', 'Berry', 'said', '.']
# hidden s:       ['.', 'DET', 'NOUN', 'VERB', 'VERB', 'PRT', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.', 'NOUN', 'VERB', '.']
# predictions:    ['.', 'DET', 'NOUN', 'VERB', 'NOUN', 'ADP', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.', 'NOUN', 'VERB', '.']
# DET: {'TP': 2275, 'FP': 184, 'TN': 16648, 'FN': 23}
# NOUN: {'TP': 4734, 'FP': 1146, 'TN': 14065, 'FN': 147}
# ADJ: {'TP': 956, 'FP': 89, 'TN': 17396, 'FN': 594}
# VERB: {'TP': 2173, 'FP': 100, 'TN': 16240, 'FN': 533}
# ADP: {'TP': 2333, 'FP': 476, 'TN': 16587, 'FN': 26}
# .: {'TP': 2298, 'FP': 13, 'TN': 16648, 'FN': 0}
# ADV: {'TP': 590, 'FP': 17, 'TN': 18105, 'FN': 251}
# CONJ: {'TP': 562, 'FP': 2, 'TN': 18368, 'FN': 16}
# PRT: {'TP': 220, 'FP': 8, 'TN': 18451, 'FN': 275}
# PRON: {'TP': 501, 'FP': 2, 'TN': 18412, 'FN': 33}
# NUM: {'TP': 263, 'FP': 0, 'TN': 18575, 'FN': 108}
# X: {'TP': 4, 'FP': 0, 'TN': 18911, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1146 counts.
# Tag with the most false negative is:  ADJ with 594 counts.
# sentence:       ['``', 'I', 'figured', 'he', 'was', 'sick', "''", '.']
# hidden s:       ['.', 'PRON', 'VERB', 'PRON', 'VERB', 'ADJ', '.', '.']
# predictions:    ['.', 'PRON', 'VERB', 'PRON', 'VERB', 'NOUN', '.', '.']
# DET: {'TP': 2275, 'FP': 184, 'TN': 16656, 'FN': 23}
# NOUN: {'TP': 4734, 'FP': 1147, 'TN': 14073, 'FN': 147}
# ADJ: {'TP': 956, 'FP': 89, 'TN': 17403, 'FN': 595}
# VERB: {'TP': 2175, 'FP': 100, 'TN': 16246, 'FN': 533}
# ADP: {'TP': 2333, 'FP': 476, 'TN': 16595, 'FN': 26}
# .: {'TP': 2301, 'FP': 13, 'TN': 16653, 'FN': 0}
# ADV: {'TP': 590, 'FP': 17, 'TN': 18113, 'FN': 251}
# CONJ: {'TP': 562, 'FP': 2, 'TN': 18376, 'FN': 16}
# PRT: {'TP': 220, 'FP': 8, 'TN': 18459, 'FN': 275}
# PRON: {'TP': 503, 'FP': 2, 'TN': 18418, 'FN': 33}
# NUM: {'TP': 263, 'FP': 0, 'TN': 18583, 'FN': 108}
# X: {'TP': 4, 'FP': 0, 'TN': 18919, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1147 counts.
# Tag with the most false negative is:  ADJ with 595 counts.
# sentence:       ['John', 'Salvador', ',', 'a', 'farmer', 'from', 'Palm', 'Desert', ',', 'Calif.', ',', 'was', 'sitting', 'up', 'front', 'and', 'could', 'see', 'through', 'the', 'door', 'as', 'the', 'trio', 'entered', 'the', 'cockpit', '.']
# hidden s:       ['NOUN', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', '.', 'VERB', 'VERB', 'ADP', 'NOUN', 'CONJ', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['NOUN', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', '.', 'VERB', 'VERB', 'ADP', 'NOUN', 'CONJ', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', '.']
# DET: {'TP': 2279, 'FP': 184, 'TN': 16680, 'FN': 23}
# NOUN: {'TP': 4744, 'FP': 1147, 'TN': 14091, 'FN': 147}
# ADJ: {'TP': 956, 'FP': 89, 'TN': 17431, 'FN': 595}
# VERB: {'TP': 2180, 'FP': 100, 'TN': 16269, 'FN': 533}
# ADP: {'TP': 2337, 'FP': 476, 'TN': 16619, 'FN': 26}
# .: {'TP': 2305, 'FP': 13, 'TN': 16677, 'FN': 0}
# ADV: {'TP': 590, 'FP': 17, 'TN': 18141, 'FN': 251}
# CONJ: {'TP': 563, 'FP': 2, 'TN': 18403, 'FN': 16}
# PRT: {'TP': 220, 'FP': 8, 'TN': 18487, 'FN': 275}
# PRON: {'TP': 503, 'FP': 2, 'TN': 18446, 'FN': 33}
# NUM: {'TP': 263, 'FP': 0, 'TN': 18611, 'FN': 108}
# X: {'TP': 4, 'FP': 0, 'TN': 18947, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1147 counts.
# Tag with the most false negative is:  ADJ with 595 counts.
# sentence:       ['``', 'The', 'kid', 'had', 'a', 'automatic', ',', 'like', 'they', 'issue', 'in', 'the', 'Army', "''", ',', 'he', 'said', '.']
# hidden s:       ['.', 'DET', 'NOUN', 'VERB', 'DET', 'ADJ', '.', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', '.', '.', 'PRON', 'VERB', '.']
# predictions:    ['.', 'DET', 'NOUN', 'VERB', 'DET', 'ADJ', '.', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', '.', '.', 'PRON', 'VERB', '.']
# DET: {'TP': 2282, 'FP': 184, 'TN': 16695, 'FN': 23}
# NOUN: {'TP': 4746, 'FP': 1147, 'TN': 14107, 'FN': 147}
# ADJ: {'TP': 957, 'FP': 89, 'TN': 17448, 'FN': 595}
# VERB: {'TP': 2183, 'FP': 100, 'TN': 16284, 'FN': 533}
# ADP: {'TP': 2339, 'FP': 476, 'TN': 16635, 'FN': 26}
# .: {'TP': 2310, 'FP': 13, 'TN': 16690, 'FN': 0}
# ADV: {'TP': 590, 'FP': 17, 'TN': 18159, 'FN': 251}
# CONJ: {'TP': 563, 'FP': 2, 'TN': 18421, 'FN': 16}
# PRT: {'TP': 220, 'FP': 8, 'TN': 18505, 'FN': 275}
# PRON: {'TP': 505, 'FP': 2, 'TN': 18462, 'FN': 33}
# NUM: {'TP': 263, 'FP': 0, 'TN': 18629, 'FN': 108}
# X: {'TP': 4, 'FP': 0, 'TN': 18965, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1147 counts.
# Tag with the most false negative is:  ADJ with 595 counts.
# sentence:       ['``', 'The', 'other', 'fellow', 'had', 'a', "''", '.']
# hidden s:       ['.', 'DET', 'ADJ', 'NOUN', 'VERB', 'DET', '.', '.']
# predictions:    ['.', 'DET', 'ADJ', 'NOUN', 'VERB', 'DET', '.', '.']
# DET: {'TP': 2284, 'FP': 184, 'TN': 16701, 'FN': 23}
# NOUN: {'TP': 4747, 'FP': 1147, 'TN': 14114, 'FN': 147}
# ADJ: {'TP': 958, 'FP': 89, 'TN': 17455, 'FN': 595}
# VERB: {'TP': 2184, 'FP': 100, 'TN': 16291, 'FN': 533}
# ADP: {'TP': 2339, 'FP': 476, 'TN': 16643, 'FN': 26}
# .: {'TP': 2313, 'FP': 13, 'TN': 16695, 'FN': 0}
# ADV: {'TP': 590, 'FP': 17, 'TN': 18167, 'FN': 251}
# CONJ: {'TP': 563, 'FP': 2, 'TN': 18429, 'FN': 16}
# PRT: {'TP': 220, 'FP': 8, 'TN': 18513, 'FN': 275}
# PRON: {'TP': 505, 'FP': 2, 'TN': 18470, 'FN': 33}
# NUM: {'TP': 263, 'FP': 0, 'TN': 18637, 'FN': 108}
# X: {'TP': 4, 'FP': 0, 'TN': 18973, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1147 counts.
# Tag with the most false negative is:  ADJ with 595 counts.
# sentence:       ['Salvador', 'saw', 'the', 'youth', 'hold', 'his', 'against', 'the', 'head', 'of', 'stewardess', 'Lois', 'Carnegey', ';', ';', 'the', 'man', 'put', 'his', 'at', 'the', 'head', 'of', 'Capt.', 'Byron', 'D.', 'Rickards', '.']
# hidden s:       ['NOUN', 'VERB', 'DET', 'NOUN', 'NOUN', 'DET', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', '.', '.', 'DET', 'NOUN', 'VERB', 'DET', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', 'NOUN', '.']
# predictions:    ['NOUN', 'VERB', 'DET', 'NOUN', 'VERB', 'DET', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.', '.', 'DET', 'NOUN', 'VERB', 'DET', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2290, 'FP': 185, 'TN': 16723, 'FN': 23}
# NOUN: {'TP': 4758, 'FP': 1147, 'TN': 14129, 'FN': 149}
# ADJ: {'TP': 958, 'FP': 89, 'TN': 17483, 'FN': 595}
# VERB: {'TP': 2186, 'FP': 101, 'TN': 16317, 'FN': 533}
# ADP: {'TP': 2343, 'FP': 476, 'TN': 16667, 'FN': 26}
# .: {'TP': 2316, 'FP': 13, 'TN': 16720, 'FN': 0}
# ADV: {'TP': 590, 'FP': 17, 'TN': 18195, 'FN': 251}
# CONJ: {'TP': 563, 'FP': 2, 'TN': 18457, 'FN': 16}
# PRT: {'TP': 220, 'FP': 8, 'TN': 18541, 'FN': 275}
# PRON: {'TP': 505, 'FP': 2, 'TN': 18498, 'FN': 33}
# NUM: {'TP': 263, 'FP': 0, 'TN': 18665, 'FN': 108}
# X: {'TP': 4, 'FP': 0, 'TN': 19001, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1147 counts.
# Tag with the most false negative is:  ADJ with 595 counts.
# sentence:       ['To', 'Rickards', ',', 'a', '52-year-old', 'veteran', '30', 'years', 'in', 'the', 'air', ',', 'it', 'was', 'an', 'old', 'story', ':', 'His', 'plane', 'was', 'being', 'hijacked', 'in', 'mid-flight', 'again', 'much', 'as', 'it', 'had', 'happened', 'in', '1930', ',', 'when', 'Peruvian', 'rebels', 'made', 'him', 'land', 'a', 'Ford', 'tri-motor', 'at', 'Arequipa', '.']
# hidden s:       ['ADP', 'NOUN', '.', 'DET', 'ADJ', 'NOUN', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'DET', 'ADJ', 'NOUN', '.', 'DET', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADV', 'ADJ', 'ADP', 'PRON', 'VERB', 'VERB', 'ADP', 'NUM', '.', 'ADV', 'ADJ', 'NOUN', 'VERB', 'PRON', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['ADP', 'NOUN', '.', 'DET', 'NOUN', 'NOUN', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'DET', 'ADJ', 'NOUN', '.', 'DET', 'NOUN', 'VERB', 'VERB', 'NOUN', 'ADP', 'NOUN', 'ADV', 'ADJ', 'ADP', 'PRON', 'VERB', 'VERB', 'ADP', 'NUM', '.', 'ADV', 'ADP', 'NOUN', 'VERB', 'PRON', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.']
# DET: {'TP': 2295, 'FP': 185, 'TN': 16764, 'FN': 23}
# NOUN: {'TP': 4769, 'FP': 1149, 'TN': 14164, 'FN': 149}
# ADJ: {'TP': 960, 'FP': 89, 'TN': 17525, 'FN': 597}
# VERB: {'TP': 2193, 'FP': 101, 'TN': 16355, 'FN': 534}
# ADP: {'TP': 2349, 'FP': 477, 'TN': 16707, 'FN': 26}
# .: {'TP': 2321, 'FP': 13, 'TN': 16761, 'FN': 0}
# ADV: {'TP': 592, 'FP': 17, 'TN': 18239, 'FN': 251}
# CONJ: {'TP': 563, 'FP': 2, 'TN': 18503, 'FN': 16}
# PRT: {'TP': 220, 'FP': 8, 'TN': 18587, 'FN': 275}
# PRON: {'TP': 508, 'FP': 2, 'TN': 18541, 'FN': 33}
# NUM: {'TP': 265, 'FP': 0, 'TN': 18709, 'FN': 108}
# X: {'TP': 4, 'FP': 0, 'TN': 19047, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1149 counts.
# Tag with the most false negative is:  ADJ with 597 counts.
# sentence:       ['But', 'last', "week's", 'pirates', ',', 'like', 'the', 'Cuban-American', 'who', 'recently', 'hijacked', 'an', 'Eastern', 'Airlines', 'Electra', '(', 'Newsweek', ',', 'Aug.', '7', ')', ',', 'wanted', 'to', 'go', 'to', 'Havana', '.']
# hidden s:       ['CONJ', 'ADJ', 'NOUN', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'PRON', 'ADV', 'VERB', 'DET', 'ADJ', 'NOUN', 'NOUN', '.', 'NOUN', '.', 'NOUN', 'NUM', '.', '.', 'VERB', 'PRT', 'VERB', 'ADP', 'NOUN', '.']
# predictions:    ['CONJ', 'ADJ', 'NOUN', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'PRON', 'ADV', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', '.', 'NOUN', '.', 'NOUN', 'NUM', '.', '.', 'VERB', 'PRT', 'VERB', 'ADP', 'NOUN', '.']
# DET: {'TP': 2297, 'FP': 185, 'TN': 16790, 'FN': 23}
# NOUN: {'TP': 4777, 'FP': 1149, 'TN': 14184, 'FN': 149}
# ADJ: {'TP': 962, 'FP': 89, 'TN': 17551, 'FN': 597}
# VERB: {'TP': 2195, 'FP': 101, 'TN': 16380, 'FN': 535}
# ADP: {'TP': 2351, 'FP': 478, 'TN': 16733, 'FN': 26}
# .: {'TP': 2327, 'FP': 13, 'TN': 16783, 'FN': 0}
# ADV: {'TP': 593, 'FP': 17, 'TN': 18266, 'FN': 251}
# CONJ: {'TP': 564, 'FP': 2, 'TN': 18530, 'FN': 16}
# PRT: {'TP': 221, 'FP': 8, 'TN': 18614, 'FN': 275}
# PRON: {'TP': 509, 'FP': 2, 'TN': 18568, 'FN': 33}
# NUM: {'TP': 266, 'FP': 0, 'TN': 18736, 'FN': 108}
# X: {'TP': 4, 'FP': 0, 'TN': 19075, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1149 counts.
# Tag with the most false negative is:  ADJ with 597 counts.
# sentence:       ['Stalling', ':', '``', 'Tell', 'your', 'company', 'there', 'are', 'four', 'of', 'us', 'here', 'with', 'guns', "''", ',', 'the', 'elder', 'man', 'told', 'Rickards', '.']
# hidden s:       ['VERB', '.', '.', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'NUM', 'ADP', 'PRON', 'ADV', 'ADP', 'NOUN', '.', '.', 'DET', 'ADJ', 'NOUN', 'VERB', 'NOUN', '.']
# predictions:    ['NOUN', '.', '.', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'NUM', 'ADP', 'PRON', 'ADV', 'ADP', 'NOUN', '.', '.', 'DET', 'NOUN', 'NOUN', 'VERB', 'NOUN', '.']
# DET: {'TP': 2299, 'FP': 185, 'TN': 16810, 'FN': 23}
# NOUN: {'TP': 4781, 'FP': 1151, 'TN': 14202, 'FN': 149}
# ADJ: {'TP': 962, 'FP': 89, 'TN': 17572, 'FN': 598}
# VERB: {'TP': 2198, 'FP': 101, 'TN': 16398, 'FN': 536}
# ADP: {'TP': 2353, 'FP': 478, 'TN': 16753, 'FN': 26}
# .: {'TP': 2332, 'FP': 13, 'TN': 16800, 'FN': 0}
# ADV: {'TP': 594, 'FP': 17, 'TN': 18287, 'FN': 251}
# CONJ: {'TP': 564, 'FP': 2, 'TN': 18552, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18635, 'FN': 275}
# PRON: {'TP': 510, 'FP': 2, 'TN': 18589, 'FN': 33}
# NUM: {'TP': 267, 'FP': 0, 'TN': 18757, 'FN': 108}
# X: {'TP': 4, 'FP': 0, 'TN': 19097, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1151 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# sentence:       ['The', 'pilot', 'radioed', 'El', 'Paso', 'International', 'Airport', 'with', 'just', 'that', 'message', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'ADP', 'ADV', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'ADP', 'ADV', 'ADP', 'NOUN', '.']
# DET: {'TP': 2300, 'FP': 185, 'TN': 16820, 'FN': 24}
# NOUN: {'TP': 4786, 'FP': 1152, 'TN': 14209, 'FN': 149}
# ADJ: {'TP': 963, 'FP': 89, 'TN': 17583, 'FN': 598}
# VERB: {'TP': 2198, 'FP': 101, 'TN': 16409, 'FN': 537}
# ADP: {'TP': 2354, 'FP': 479, 'TN': 16764, 'FN': 26}
# .: {'TP': 2333, 'FP': 13, 'TN': 16811, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18298, 'FN': 251}
# CONJ: {'TP': 564, 'FP': 2, 'TN': 18564, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18647, 'FN': 275}
# PRON: {'TP': 510, 'FP': 2, 'TN': 18601, 'FN': 33}
# NUM: {'TP': 267, 'FP': 0, 'TN': 18769, 'FN': 108}
# X: {'TP': 4, 'FP': 0, 'TN': 19109, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1152 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# sentence:       ['But', ',', 'he', 'told', 'the', '``', 'skyjackers', "''", ',', 'the', '707', "didn't", 'carry', 'enough', 'fuel', 'to', 'reach', 'Havana', ';', ';', 'they', 'would', 'have', 'to', 'refuel', 'at', 'El', 'Paso', '.']
# hidden s:       ['CONJ', '.', 'PRON', 'VERB', 'DET', '.', 'NOUN', '.', '.', 'DET', 'NUM', 'VERB', 'VERB', 'ADJ', 'NOUN', 'PRT', 'VERB', 'NOUN', '.', '.', 'PRON', 'VERB', 'VERB', 'PRT', 'VERB', 'ADP', 'NOUN', 'NOUN', '.']
# predictions:    ['CONJ', '.', 'PRON', 'VERB', 'DET', '.', 'NOUN', '.', '.', 'DET', 'NOUN', 'VERB', 'VERB', 'ADJ', 'NOUN', 'ADP', 'VERB', 'NOUN', '.', '.', 'PRON', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2302, 'FP': 185, 'TN': 16847, 'FN': 24}
# NOUN: {'TP': 4791, 'FP': 1154, 'TN': 14233, 'FN': 149}
# ADJ: {'TP': 964, 'FP': 89, 'TN': 17611, 'FN': 598}
# VERB: {'TP': 2204, 'FP': 101, 'TN': 16431, 'FN': 538}
# ADP: {'TP': 2355, 'FP': 481, 'TN': 16792, 'FN': 26}
# .: {'TP': 2340, 'FP': 13, 'TN': 16833, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18327, 'FN': 251}
# CONJ: {'TP': 565, 'FP': 2, 'TN': 18592, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18674, 'FN': 277}
# PRON: {'TP': 512, 'FP': 2, 'TN': 18628, 'FN': 33}
# NUM: {'TP': 267, 'FP': 0, 'TN': 18797, 'FN': 109}
# X: {'TP': 4, 'FP': 0, 'TN': 19138, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1154 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# sentence:       ['Most', 'passengers', "didn't", 'know', 'what', 'had', 'happened', 'until', 'they', 'got', 'on', 'the', 'ground', '.']
# hidden s:       ['ADJ', 'NOUN', 'VERB', 'VERB', 'DET', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['ADJ', 'NOUN', 'VERB', 'VERB', 'DET', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2304, 'FP': 185, 'TN': 16859, 'FN': 24}
# NOUN: {'TP': 4793, 'FP': 1154, 'TN': 14245, 'FN': 149}
# ADJ: {'TP': 965, 'FP': 89, 'TN': 17624, 'FN': 598}
# VERB: {'TP': 2209, 'FP': 101, 'TN': 16440, 'FN': 538}
# ADP: {'TP': 2357, 'FP': 481, 'TN': 16804, 'FN': 26}
# .: {'TP': 2341, 'FP': 13, 'TN': 16846, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18341, 'FN': 251}
# CONJ: {'TP': 565, 'FP': 2, 'TN': 18606, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18688, 'FN': 277}
# PRON: {'TP': 513, 'FP': 2, 'TN': 18641, 'FN': 33}
# NUM: {'TP': 267, 'FP': 0, 'TN': 18811, 'FN': 109}
# X: {'TP': 4, 'FP': 0, 'TN': 19152, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1154 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# sentence:       ['Jerry', 'McCauley', 'of', 'Sacramento', ',', 'Calif.', ',', 'one', 'of', 'some', 'twenty', 'Air', 'Force', 'recruits', 'on', 'board', ',', 'awoke', 'from', 'a', 'nap', 'in', 'confusion', '.']
# hidden s:       ['NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'NUM', 'ADP', 'DET', 'NUM', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'NOUN', 'ADP', 'DET', 'NUM', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.']
# DET: {'TP': 2306, 'FP': 185, 'TN': 16881, 'FN': 24}
# NOUN: {'TP': 4803, 'FP': 1156, 'TN': 14259, 'FN': 149}
# ADJ: {'TP': 965, 'FP': 89, 'TN': 17648, 'FN': 598}
# VERB: {'TP': 2209, 'FP': 101, 'TN': 16463, 'FN': 539}
# ADP: {'TP': 2362, 'FP': 481, 'TN': 16823, 'FN': 26}
# .: {'TP': 2345, 'FP': 13, 'TN': 16866, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18365, 'FN': 251}
# CONJ: {'TP': 565, 'FP': 2, 'TN': 18630, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18712, 'FN': 277}
# PRON: {'TP': 513, 'FP': 2, 'TN': 18665, 'FN': 33}
# NUM: {'TP': 268, 'FP': 0, 'TN': 18833, 'FN': 110}
# X: {'TP': 4, 'FP': 0, 'TN': 19176, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1156 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# sentence:       ['``', 'The', 'old', 'man', 'came', 'from', 'the', 'front', 'of', 'the', 'plane', 'and', 'said', 'he', 'wanted', 'four', 'volunteers', 'to', 'go', 'to', 'Cuba', "''", ',', 'McCauley', 'said', ',', '``', 'and', 'like', 'a', 'nut', 'I', 'raised', 'my', 'hand', '.']
# hidden s:       ['.', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'VERB', 'PRON', 'VERB', 'NUM', 'NOUN', 'PRT', 'VERB', 'ADP', 'NOUN', '.', '.', 'NOUN', 'VERB', '.', '.', 'CONJ', 'ADP', 'DET', 'NOUN', 'PRON', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['.', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'VERB', 'PRON', 'VERB', 'NUM', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', '.', 'NOUN', 'VERB', '.', '.', 'CONJ', 'VERB', 'DET', 'NOUN', 'PRON', 'VERB', 'DET', 'NOUN', '.']
# DET: {'TP': 2311, 'FP': 185, 'TN': 16912, 'FN': 24}
# NOUN: {'TP': 4811, 'FP': 1157, 'TN': 14287, 'FN': 149}
# ADJ: {'TP': 966, 'FP': 89, 'TN': 17683, 'FN': 598}
# VERB: {'TP': 2214, 'FP': 102, 'TN': 16493, 'FN': 540}
# ADP: {'TP': 2365, 'FP': 482, 'TN': 16855, 'FN': 27}
# .: {'TP': 2351, 'FP': 13, 'TN': 16896, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18401, 'FN': 251}
# CONJ: {'TP': 567, 'FP': 2, 'TN': 18664, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18747, 'FN': 278}
# PRON: {'TP': 515, 'FP': 2, 'TN': 18699, 'FN': 33}
# NUM: {'TP': 269, 'FP': 0, 'TN': 18868, 'FN': 110}
# X: {'TP': 4, 'FP': 0, 'TN': 19212, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1157 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# sentence:       ['I', 'thought', 'he', 'was', 'the', 'Air', 'Force', 'recruiter', "''", '.']
# hidden s:       ['PRON', 'VERB', 'PRON', 'VERB', 'DET', 'NOUN', 'NOUN', 'NOUN', '.', '.']
# predictions:    ['PRON', 'VERB', 'PRON', 'VERB', 'DET', 'NOUN', 'NOUN', 'NOUN', '.', '.']
# DET: {'TP': 2312, 'FP': 185, 'TN': 16921, 'FN': 24}
# NOUN: {'TP': 4814, 'FP': 1157, 'TN': 14294, 'FN': 149}
# ADJ: {'TP': 966, 'FP': 89, 'TN': 17693, 'FN': 598}
# VERB: {'TP': 2216, 'FP': 102, 'TN': 16501, 'FN': 540}
# ADP: {'TP': 2365, 'FP': 482, 'TN': 16865, 'FN': 27}
# .: {'TP': 2353, 'FP': 13, 'TN': 16904, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18411, 'FN': 251}
# CONJ: {'TP': 567, 'FP': 2, 'TN': 18674, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18757, 'FN': 278}
# PRON: {'TP': 517, 'FP': 2, 'TN': 18707, 'FN': 33}
# NUM: {'TP': 269, 'FP': 0, 'TN': 18878, 'FN': 110}
# X: {'TP': 4, 'FP': 0, 'TN': 19222, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1157 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# sentence:       ['What', 'the', 'man', 'wanted', 'was', 'four', 'persons', 'to', 'volunteer', 'as', 'hostages', ',', 'along', 'with', 'the', 'crew', '.']
# hidden s:       ['DET', 'DET', 'NOUN', 'VERB', 'VERB', 'NUM', 'NOUN', 'PRT', 'VERB', 'ADP', 'NOUN', '.', 'ADP', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'DET', 'NOUN', 'VERB', 'VERB', 'NUM', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2315, 'FP': 185, 'TN': 16935, 'FN': 24}
# NOUN: {'TP': 4818, 'FP': 1158, 'TN': 14307, 'FN': 149}
# ADJ: {'TP': 966, 'FP': 89, 'TN': 17710, 'FN': 598}
# VERB: {'TP': 2218, 'FP': 102, 'TN': 16515, 'FN': 541}
# ADP: {'TP': 2368, 'FP': 483, 'TN': 16879, 'FN': 27}
# .: {'TP': 2355, 'FP': 13, 'TN': 16919, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18428, 'FN': 251}
# CONJ: {'TP': 567, 'FP': 2, 'TN': 18691, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18773, 'FN': 279}
# PRON: {'TP': 517, 'FP': 2, 'TN': 18724, 'FN': 33}
# NUM: {'TP': 270, 'FP': 0, 'TN': 18894, 'FN': 110}
# X: {'TP': 4, 'FP': 0, 'TN': 19239, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1158 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# sentence:       ['They', 'chose', 'four', ':', 'Jack', 'Casey', ',', 'who', 'works', 'for', 'Continental', 'Airlines', 'in', 'Houston', ';', ';', 'Fred', 'Mullen', 'from', 'Mercer', 'Island', ',', 'Wash.', ';', ';', 'Pfc.', 'Truman', 'Cleveland', 'of', 'St.', 'Augustine', '.']
# hidden s:       ['PRON', 'VERB', 'NUM', '.', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', '.', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', '.', '.', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.']
# predictions:    ['PRON', 'VERB', 'NUM', '.', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', '.', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', '.', '.', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2315, 'FP': 185, 'TN': 16967, 'FN': 24}
# NOUN: {'TP': 4832, 'FP': 1158, 'TN': 14325, 'FN': 149}
# ADJ: {'TP': 967, 'FP': 89, 'TN': 17741, 'FN': 598}
# VERB: {'TP': 2220, 'FP': 102, 'TN': 16545, 'FN': 541}
# ADP: {'TP': 2372, 'FP': 483, 'TN': 16907, 'FN': 27}
# .: {'TP': 2363, 'FP': 13, 'TN': 16943, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18460, 'FN': 251}
# CONJ: {'TP': 567, 'FP': 2, 'TN': 18723, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18805, 'FN': 279}
# PRON: {'TP': 519, 'FP': 2, 'TN': 18754, 'FN': 33}
# NUM: {'TP': 271, 'FP': 0, 'TN': 18925, 'FN': 110}
# X: {'TP': 4, 'FP': 0, 'TN': 19271, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1158 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# sentence:       ['Fla.', ',', 'and', 'Leonard', 'Gilman', ',', 'a', 'former', 'college', 'boxer', 'and', 'veteran', 'of', 'the', 'U.S.', 'Immigration', 'Service', 'Border', 'Patrol', '.']
# hidden s:       ['NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'DET', 'ADJ', 'NOUN', 'NOUN', 'CONJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', '.']
# predictions:    ['NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'DET', 'ADJ', 'NOUN', 'NOUN', 'CONJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2317, 'FP': 185, 'TN': 16985, 'FN': 24}
# NOUN: {'TP': 4843, 'FP': 1158, 'TN': 14334, 'FN': 149}
# ADJ: {'TP': 968, 'FP': 89, 'TN': 17760, 'FN': 598}
# VERB: {'TP': 2220, 'FP': 102, 'TN': 16565, 'FN': 541}
# ADP: {'TP': 2373, 'FP': 483, 'TN': 16926, 'FN': 27}
# .: {'TP': 2366, 'FP': 13, 'TN': 16960, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18480, 'FN': 251}
# CONJ: {'TP': 569, 'FP': 2, 'TN': 18741, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18825, 'FN': 279}
# PRON: {'TP': 519, 'FP': 2, 'TN': 18774, 'FN': 33}
# NUM: {'TP': 271, 'FP': 0, 'TN': 18945, 'FN': 110}
# X: {'TP': 4, 'FP': 0, 'TN': 19291, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1158 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# sentence:       ['Everybody', 'else', 'was', 'allowed', 'to', 'file', 'off', 'the', 'plane', 'after', 'it', 'touched', 'down', 'at', 'El', 'Paso', 'at', '4:18', 'a.m.', '.']
# hidden s:       ['NOUN', 'ADV', 'VERB', 'VERB', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'PRT', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NUM', 'ADV', '.']
# predictions:    ['NOUN', 'ADV', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'PRT', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADV', '.']
# DET: {'TP': 2318, 'FP': 185, 'TN': 17004, 'FN': 24}
# NOUN: {'TP': 4847, 'FP': 1160, 'TN': 14350, 'FN': 149}
# ADJ: {'TP': 968, 'FP': 89, 'TN': 17780, 'FN': 598}
# VERB: {'TP': 2223, 'FP': 102, 'TN': 16581, 'FN': 542}
# ADP: {'TP': 2377, 'FP': 484, 'TN': 16942, 'FN': 27}
# .: {'TP': 2367, 'FP': 13, 'TN': 16979, 'FN': 0}
# ADV: {'TP': 597, 'FP': 17, 'TN': 18498, 'FN': 251}
# CONJ: {'TP': 569, 'FP': 2, 'TN': 18761, 'FN': 16}
# PRT: {'TP': 223, 'FP': 8, 'TN': 18843, 'FN': 280}
# PRON: {'TP': 520, 'FP': 2, 'TN': 18793, 'FN': 33}
# NUM: {'TP': 271, 'FP': 0, 'TN': 18964, 'FN': 111}
# X: {'TP': 4, 'FP': 0, 'TN': 19311, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1160 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# sentence:       ['They', 'found', 'a', 'large', 'welcoming', 'group', '--', 'El', 'Paso', 'policemen', ',', 'Border', 'Patrol', ',', "sheriff's", 'deputies', ',', 'and', 'FBI', 'men', ',', 'who', 'surged', 'around', 'the', 'plane', 'with', 'rifles', 'and', 'submachine', 'guns', '.']
# hidden s:       ['PRON', 'VERB', 'DET', 'ADJ', 'VERB', 'NOUN', '.', 'NOUN', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'ADJ', 'NOUN', '.']
# predictions:    ['PRON', 'VERB', 'DET', 'ADJ', 'VERB', 'NOUN', '.', 'NOUN', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2320, 'FP': 185, 'TN': 17034, 'FN': 24}
# NOUN: {'TP': 4860, 'FP': 1161, 'TN': 14369, 'FN': 149}
# ADJ: {'TP': 969, 'FP': 89, 'TN': 17810, 'FN': 599}
# VERB: {'TP': 2226, 'FP': 102, 'TN': 16610, 'FN': 542}
# ADP: {'TP': 2379, 'FP': 484, 'TN': 16972, 'FN': 27}
# .: {'TP': 2373, 'FP': 13, 'TN': 17005, 'FN': 0}
# ADV: {'TP': 597, 'FP': 17, 'TN': 18530, 'FN': 251}
# CONJ: {'TP': 571, 'FP': 2, 'TN': 18791, 'FN': 16}
# PRT: {'TP': 223, 'FP': 8, 'TN': 18875, 'FN': 280}
# PRON: {'TP': 522, 'FP': 2, 'TN': 18823, 'FN': 33}
# NUM: {'TP': 271, 'FP': 0, 'TN': 18996, 'FN': 111}
# X: {'TP': 4, 'FP': 0, 'TN': 19343, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1161 counts.
# Tag with the most false negative is:  ADJ with 599 counts.
# sentence:       ['Other', 'FBI', 'men', ',', 'talking', 'with', 'the', 'pilot', 'from', 'the', 'tower', ',', 'conspired', 'with', 'him', 'to', 'delay', 'the', 'proposed', 'flight', 'to', 'Havana', '.']
# hidden s:       ['ADJ', 'NOUN', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'PRON', 'PRT', 'VERB', 'DET', 'VERB', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['ADJ', 'NOUN', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'NOUN', 'ADP', 'PRON', 'ADP', 'NOUN', 'DET', 'VERB', 'NOUN', 'ADP', 'NOUN', '.']
# DET: {'TP': 2323, 'FP': 185, 'TN': 17054, 'FN': 24}
# NOUN: {'TP': 4866, 'FP': 1163, 'TN': 14386, 'FN': 149}
# ADJ: {'TP': 970, 'FP': 89, 'TN': 17832, 'FN': 599}
# VERB: {'TP': 2228, 'FP': 102, 'TN': 16629, 'FN': 544}
# ADP: {'TP': 2383, 'FP': 485, 'TN': 16991, 'FN': 27}
# .: {'TP': 2376, 'FP': 13, 'TN': 17025, 'FN': 0}
# ADV: {'TP': 597, 'FP': 17, 'TN': 18553, 'FN': 251}
# CONJ: {'TP': 571, 'FP': 2, 'TN': 18814, 'FN': 16}
# PRT: {'TP': 223, 'FP': 8, 'TN': 18897, 'FN': 281}
# PRON: {'TP': 523, 'FP': 2, 'TN': 18845, 'FN': 33}
# NUM: {'TP': 271, 'FP': 0, 'TN': 19019, 'FN': 111}
# X: {'TP': 4, 'FP': 0, 'TN': 19366, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1163 counts.
# Tag with the most false negative is:  ADJ with 599 counts.
# sentence:       ['The', 'ground', 'crew', ',', 'which', 'ordinarily', 'fuels', 'a', '707', 'in', 'twenty', 'minutes', ',', 'took', 'fully', 'three', 'hours', '.']
# hidden s:       ['DET', 'NOUN', 'NOUN', '.', 'DET', 'ADV', 'VERB', 'DET', 'NUM', 'ADP', 'NUM', 'NOUN', '.', 'VERB', 'ADV', 'NUM', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'NOUN', '.', 'VERB', 'ADV', 'NUM', 'NOUN', '.']
# DET: {'TP': 2326, 'FP': 185, 'TN': 17069, 'FN': 24}
# NOUN: {'TP': 4870, 'FP': 1165, 'TN': 14400, 'FN': 149}
# ADJ: {'TP': 970, 'FP': 89, 'TN': 17850, 'FN': 599}
# VERB: {'TP': 2229, 'FP': 102, 'TN': 16645, 'FN': 545}
# ADP: {'TP': 2384, 'FP': 486, 'TN': 17008, 'FN': 27}
# .: {'TP': 2379, 'FP': 13, 'TN': 17040, 'FN': 0}
# ADV: {'TP': 598, 'FP': 17, 'TN': 18569, 'FN': 252}
# CONJ: {'TP': 571, 'FP': 2, 'TN': 18832, 'FN': 16}
# PRT: {'TP': 223, 'FP': 8, 'TN': 18915, 'FN': 281}
# PRON: {'TP': 523, 'FP': 2, 'TN': 18863, 'FN': 33}
# NUM: {'TP': 273, 'FP': 0, 'TN': 19034, 'FN': 112}
# X: {'TP': 4, 'FP': 0, 'TN': 19384, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1165 counts.
# Tag with the most false negative is:  ADJ with 599 counts.
# sentence:       ['Still', 'more', 'time', 'was', 'consumed', 'while', 'the', 'pilot', ',', 'at', 'the', 'radioed', 'suggestion', 'of', 'Continental', 'president', 'Robert', 'Six', ',', 'tried', 'to', 'persuade', 'the', 'armed', 'pair', 'to', 'swap', 'the', 'Boeing', 'jet', 'for', 'a', 'propeller-driven', 'Douglas', 'Aj', '.']
# hidden s:       ['ADV', 'ADJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'DET', 'VERB', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', 'NOUN', '.', 'VERB', 'PRT', 'VERB', 'DET', 'VERB', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', '.']
# predictions:    ['ADV', 'ADJ', 'NOUN', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', 'NUM', '.', 'VERB', 'PRT', 'VERB', 'DET', 'VERB', 'NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2331, 'FP': 185, 'TN': 17100, 'FN': 24}
# NOUN: {'TP': 4880, 'FP': 1169, 'TN': 14425, 'FN': 150}
# ADJ: {'TP': 972, 'FP': 89, 'TN': 17883, 'FN': 600}
# VERB: {'TP': 2233, 'FP': 102, 'TN': 16674, 'FN': 548}
# ADP: {'TP': 2388, 'FP': 487, 'TN': 17040, 'FN': 27}
# .: {'TP': 2382, 'FP': 13, 'TN': 17073, 'FN': 0}
# ADV: {'TP': 599, 'FP': 17, 'TN': 18604, 'FN': 252}
# CONJ: {'TP': 571, 'FP': 2, 'TN': 18868, 'FN': 16}
# PRT: {'TP': 224, 'FP': 8, 'TN': 18949, 'FN': 282}
# PRON: {'TP': 523, 'FP': 2, 'TN': 18899, 'FN': 33}
# NUM: {'TP': 273, 'FP': 1, 'TN': 19070, 'FN': 112}
# X: {'TP': 4, 'FP': 0, 'TN': 19420, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1169 counts.
# Tag with the most false negative is:  ADJ with 600 counts.
# sentence:       ['Actually', ',', 'the', 'officers', 'on', 'the', 'ground', 'had', 'no', 'intention', 'of', 'letting', 'the', 'hijackers', 'get', 'away', 'with', 'any', 'kind', 'of', 'an', 'airplane', ';', ';', 'they', 'had', 'orders', 'to', 'that', 'effect', 'straight', 'from', 'President', 'Kennedy', ',', 'who', 'thought', 'at', 'first', ',', 'as', 'did', 'most', 'others', ',', 'that', 'it', 'was', 'four', 'followers', 'of', "Cuba's", 'Fidel', 'Castro', 'who', 'had', 'taken', 'over', 'the', '707', '.']
# hidden s:       ['ADV', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'VERB', 'DET', 'NOUN', 'VERB', 'ADV', 'ADP', 'DET', 'ADJ', 'ADP', 'DET', 'NOUN', '.', '.', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADV', 'ADP', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'ADJ', '.', 'ADV', 'VERB', 'ADJ', 'NOUN', '.', 'ADP', 'PRON', 'VERB', 'NUM', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', 'PRON', 'VERB', 'VERB', 'PRT', 'DET', 'NUM', '.']
# predictions:    ['ADV', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'VERB', 'DET', 'NOUN', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADJ', 'ADP', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'ADJ', '.', 'ADP', 'VERB', 'ADJ', 'NOUN', '.', 'ADP', 'PRON', 'VERB', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2339, 'FP': 186, 'TN': 17153, 'FN': 24}
# NOUN: {'TP': 4893, 'FP': 1171, 'TN': 14472, 'FN': 151}
# ADJ: {'TP': 974, 'FP': 90, 'TN': 17941, 'FN': 601}
# VERB: {'TP': 2242, 'FP': 102, 'TN': 16726, 'FN': 548}
# ADP: {'TP': 2397, 'FP': 489, 'TN': 17092, 'FN': 27}
# .: {'TP': 2389, 'FP': 13, 'TN': 17127, 'FN': 0}
# ADV: {'TP': 601, 'FP': 17, 'TN': 18661, 'FN': 254}
# CONJ: {'TP': 571, 'FP': 2, 'TN': 18929, 'FN': 16}
# PRT: {'TP': 224, 'FP': 8, 'TN': 19009, 'FN': 283}
# PRON: {'TP': 527, 'FP': 2, 'TN': 18956, 'FN': 33}
# NUM: {'TP': 274, 'FP': 1, 'TN': 19129, 'FN': 113}
# X: {'TP': 4, 'FP': 0, 'TN': 19481, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1171 counts.
# Tag with the most false negative is:  ADJ with 601 counts.
# sentence:       ['Mr.', 'Kennedy', 'had', 'been', 'informed', 'early', 'in', 'the', 'day', 'of', 'the', 'attempt', 'to', 'steal', 'the', 'plane', ',', 'kept', 'in', 'touch', 'throughout', 'by', 'telephone', '.']
# hidden s:       ['NOUN', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'NOUN', 'ADV', 'ADP', 'NOUN', '.']
# predictions:    ['NOUN', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'NOUN', 'ADP', 'ADP', 'NOUN', '.']
# DET: {'TP': 2342, 'FP': 186, 'TN': 17174, 'FN': 24}
# NOUN: {'TP': 4900, 'FP': 1172, 'TN': 14489, 'FN': 151}
# ADJ: {'TP': 974, 'FP': 90, 'TN': 17965, 'FN': 601}
# VERB: {'TP': 2246, 'FP': 102, 'TN': 16745, 'FN': 549}
# ADP: {'TP': 2401, 'FP': 491, 'TN': 17112, 'FN': 27}
# .: {'TP': 2391, 'FP': 13, 'TN': 17149, 'FN': 0}
# ADV: {'TP': 602, 'FP': 17, 'TN': 18683, 'FN': 255}
# CONJ: {'TP': 571, 'FP': 2, 'TN': 18953, 'FN': 16}
# PRT: {'TP': 224, 'FP': 8, 'TN': 19032, 'FN': 284}
# PRON: {'TP': 527, 'FP': 2, 'TN': 18980, 'FN': 33}
# NUM: {'TP': 274, 'FP': 1, 'TN': 19153, 'FN': 113}
# X: {'TP': 4, 'FP': 0, 'TN': 19505, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1172 counts.
# Tag with the most false negative is:  ADJ with 601 counts.
# sentence:       ['At', 'one', 'time', ',', 'while', 'still', 'under', 'the', 'impression', 'that', 'he', 'was', 'dealing', 'with', 'a', 'Cuban', 'plot', ',', 'the', 'President', 'talked', 'about', 'invoking', 'a', 'total', 'embargo', 'on', 'trade', 'with', 'Cuba', '.']
# hidden s:       ['ADP', 'NUM', 'NOUN', '.', 'ADP', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'DET', 'NOUN', 'VERB', 'ADP', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['ADP', 'NOUN', 'NOUN', '.', 'NOUN', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'VERB', 'ADP', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', '.']
# DET: {'TP': 2346, 'FP': 186, 'TN': 17201, 'FN': 24}
# NOUN: {'TP': 4908, 'FP': 1175, 'TN': 14512, 'FN': 151}
# ADJ: {'TP': 974, 'FP': 90, 'TN': 17995, 'FN': 602}
# VERB: {'TP': 2250, 'FP': 102, 'TN': 16772, 'FN': 549}
# ADP: {'TP': 2408, 'FP': 491, 'TN': 17135, 'FN': 28}
# .: {'TP': 2394, 'FP': 13, 'TN': 17177, 'FN': 0}
# ADV: {'TP': 603, 'FP': 17, 'TN': 18713, 'FN': 255}
# CONJ: {'TP': 571, 'FP': 2, 'TN': 18984, 'FN': 16}
# PRT: {'TP': 224, 'FP': 8, 'TN': 19063, 'FN': 284}
# PRON: {'TP': 528, 'FP': 2, 'TN': 19010, 'FN': 33}
# NUM: {'TP': 274, 'FP': 1, 'TN': 19183, 'FN': 114}
# X: {'TP': 4, 'FP': 0, 'TN': 19536, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1175 counts.
# Tag with the most false negative is:  ADJ with 602 counts.
# sentence:       ['As', 'the', 'morning', 'wore', 'on', 'and', 'a', 'blazing', 'West', 'Texas', 'sun', 'wiped', 'the', 'shadows', 'off', 'the', 'Franklin', 'Mountains', ',', 'police', 'got', 'close', 'enough', 'to', 'the', 'plane', 'to', 'pry', 'into', 'the', 'baggage', 'compartment', '.']
# hidden s:       ['ADP', 'DET', 'NOUN', 'VERB', 'PRT', 'CONJ', 'DET', 'VERB', 'ADJ', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'NOUN', 'VERB', 'ADV', 'ADV', 'ADP', 'DET', 'NOUN', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', '.']
# predictions:    ['ADP', 'DET', 'NOUN', 'VERB', 'ADP', 'CONJ', 'DET', 'VERB', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'NOUN', 'VERB', 'VERB', 'ADJ', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2352, 'FP': 186, 'TN': 17228, 'FN': 24}
# NOUN: {'TP': 4918, 'FP': 1177, 'TN': 14535, 'FN': 151}
# ADJ: {'TP': 974, 'FP': 91, 'TN': 18027, 'FN': 603}
# VERB: {'TP': 2254, 'FP': 103, 'TN': 16800, 'FN': 550}
# ADP: {'TP': 2412, 'FP': 493, 'TN': 17164, 'FN': 28}
# .: {'TP': 2396, 'FP': 13, 'TN': 17208, 'FN': 0}
# ADV: {'TP': 603, 'FP': 17, 'TN': 18744, 'FN': 257}
# CONJ: {'TP': 572, 'FP': 2, 'TN': 19016, 'FN': 16}
# PRT: {'TP': 224, 'FP': 8, 'TN': 19094, 'FN': 286}
# PRON: {'TP': 528, 'FP': 2, 'TN': 19043, 'FN': 33}
# NUM: {'TP': 274, 'FP': 1, 'TN': 19216, 'FN': 114}
# X: {'TP': 4, 'FP': 0, 'TN': 19569, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1177 counts.
# Tag with the most false negative is:  ADJ with 603 counts.
# sentence:       ['From', 'the', 'luggage', ',', 'they', 'learned', 'that', 'the', 'two', 'air', 'pirates', ',', 'far', 'from', 'being', 'Cubans', ',', 'were', 'native', 'Americans', ',', 'subsequently', 'identified', 'as', 'Leon', 'Bearden', ',', '50-year-old', 'ex-convict', 'from', 'Coolidge', ',', 'Ariz.', ',', 'and', 'his', 'son', ',', 'Cody', ',', '16', ',', 'a', 'high-school', 'junior', '.']
# hidden s:       ['ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'DET', 'NUM', 'NOUN', 'NOUN', '.', 'ADV', 'ADP', 'VERB', 'NOUN', '.', 'VERB', 'ADJ', 'NOUN', '.', 'ADV', 'VERB', 'ADP', 'NOUN', 'NOUN', '.', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', '.', 'NOUN', '.', 'NUM', '.', 'DET', 'NOUN', 'NOUN', '.']
# predictions:    ['ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'DET', 'NUM', 'NOUN', 'NOUN', '.', 'ADV', 'ADP', 'VERB', 'NOUN', '.', 'VERB', 'NOUN', 'NOUN', '.', 'NOUN', 'VERB', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', '.', 'NOUN', '.', 'NUM', '.', 'DET', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2356, 'FP': 186, 'TN': 17270, 'FN': 24}
# NOUN: {'TP': 4932, 'FP': 1180, 'TN': 14567, 'FN': 151}
# ADJ: {'TP': 974, 'FP': 91, 'TN': 18071, 'FN': 605}
# VERB: {'TP': 2258, 'FP': 103, 'TN': 16842, 'FN': 550}
# ADP: {'TP': 2417, 'FP': 493, 'TN': 17205, 'FN': 28}
# .: {'TP': 2407, 'FP': 13, 'TN': 17243, 'FN': 0}
# ADV: {'TP': 604, 'FP': 17, 'TN': 18788, 'FN': 258}
# CONJ: {'TP': 573, 'FP': 2, 'TN': 19061, 'FN': 16}
# PRT: {'TP': 224, 'FP': 8, 'TN': 19140, 'FN': 286}
# PRON: {'TP': 529, 'FP': 2, 'TN': 19088, 'FN': 33}
# NUM: {'TP': 276, 'FP': 1, 'TN': 19260, 'FN': 114}
# X: {'TP': 4, 'FP': 0, 'TN': 19615, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1180 counts.
# Tag with the most false negative is:  ADJ with 605 counts.
# sentence:       ['Tension', 'The', 'heat', 'and', 'strain', 'began', 'to', 'tell', 'on', 'the', 'Beardens', '.']
# hidden s:       ['NOUN', 'DET', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['ADP', 'DET', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2358, 'FP': 186, 'TN': 17280, 'FN': 24}
# NOUN: {'TP': 4935, 'FP': 1180, 'TN': 14575, 'FN': 152}
# ADJ: {'TP': 974, 'FP': 91, 'TN': 18083, 'FN': 605}
# VERB: {'TP': 2260, 'FP': 103, 'TN': 16852, 'FN': 550}
# ADP: {'TP': 2418, 'FP': 494, 'TN': 17216, 'FN': 28}
# .: {'TP': 2408, 'FP': 13, 'TN': 17254, 'FN': 0}
# ADV: {'TP': 604, 'FP': 17, 'TN': 18800, 'FN': 258}
# CONJ: {'TP': 574, 'FP': 2, 'TN': 19072, 'FN': 16}
# PRT: {'TP': 225, 'FP': 8, 'TN': 19151, 'FN': 286}
# PRON: {'TP': 529, 'FP': 2, 'TN': 19100, 'FN': 33}
# NUM: {'TP': 276, 'FP': 1, 'TN': 19272, 'FN': 114}
# X: {'TP': 4, 'FP': 0, 'TN': 19627, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1180 counts.
# Tag with the most false negative is:  ADJ with 605 counts.
# sentence:       ['The', 'father', ',', 'by', 'accident', 'or', 'perhaps', 'to', 'show', ',', 'as', 'he', 'said', ',', '``', 'we', 'mean', 'business', "''", ',', 'took', 'the', 'and', 'fired', 'a', 'slug', 'between', 'the', 'legs', 'of', 'Second', 'Officer', 'Norman', 'Simmons', '.']
# hidden s:       ['DET', 'NOUN', '.', 'ADP', 'NOUN', 'CONJ', 'ADV', 'PRT', 'VERB', '.', 'ADP', 'PRON', 'VERB', '.', '.', 'PRON', 'VERB', 'NOUN', '.', '.', 'VERB', 'DET', 'CONJ', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', 'NOUN', '.']
# ...
# NOUN: {'TP': 6322, 'FP': 1453, 'TN': 18331, 'FN': 199}
# ADJ: {'TP': 1254, 'FP': 120, 'TN': 22870, 'FN': 728}
# VERB: {'TP': 2869, 'FP': 128, 'TN': 21286, 'FN': 697}
# ADP: {'TP': 3110, 'FP': 624, 'TN': 21709, 'FN': 33}
# .: {'TP': 3060, 'FP': 14, 'TN': 21792, 'FN': 0}
# ADV: {'TP': 744, 'FP': 18, 'TN': 23783, 'FN': 325}
# CONJ: {'TP': 707, 'FP': 3, 'TN': 24129, 'FN': 16}
# PRT: {'TP': 287, 'FP': 12, 'TN': 24198, 'FN': 367}
# PRON: {'TP': 603, 'FP': 2, 'TN': 24205, 'FN': 44}
# NUM: {'TP': 343, 'FP': 1, 'TN': 24370, 'FN': 139}
# X: {'TP': 4, 'FP': 0, 'TN': 24811, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1453 counts.
# Tag with the most false negative is:  ADJ with 728 counts.
# sentence:       ['We', 'must', 'not', 'permit', 'our', 'society', 'to', 'become', 'a', 'slave', 'to', 'the', 'scientific', 'age', ',', 'as', 'might', 'well', 'happen', 'without', 'the', 'cultural', 'and', 'spiritual', 'restraint', 'that', 'comes', 'from', 'the', 'development', 'of', 'the', 'human', 'mind', 'through', 'wisdom', 'absorbed', 'from', 'the', 'written', 'word', '.']
# hidden s:       ['PRON', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADP', 'VERB', 'ADV', 'VERB', 'ADP', 'DET', 'ADJ', 'CONJ', 'ADJ', 'NOUN', 'DET', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', '.']
# predictions:    ['PRON', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADP', 'VERB', 'ADV', 'VERB', 'ADP', 'DET', 'ADJ', 'CONJ', 'NOUN', 'NOUN', 'ADP', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', '.']
# DET: {'TP': 2943, 'FP': 238, 'TN': 21922, 'FN': 29}
# NOUN: {'TP': 6331, 'FP': 1454, 'TN': 18364, 'FN': 199}
# ADJ: {'TP': 1256, 'FP': 120, 'TN': 22909, 'FN': 729}
# VERB: {'TP': 2877, 'FP': 128, 'TN': 21320, 'FN': 697}
# ADP: {'TP': 3117, 'FP': 626, 'TN': 21744, 'FN': 33}
# .: {'TP': 3062, 'FP': 14, 'TN': 21832, 'FN': 0}
# ADV: {'TP': 746, 'FP': 18, 'TN': 23823, 'FN': 325}
# CONJ: {'TP': 708, 'FP': 3, 'TN': 24170, 'FN': 16}
# PRT: {'TP': 287, 'FP': 12, 'TN': 24239, 'FN': 368}
# PRON: {'TP': 604, 'FP': 2, 'TN': 24246, 'FN': 44}
# NUM: {'TP': 343, 'FP': 1, 'TN': 24412, 'FN': 139}
# X: {'TP': 4, 'FP': 0, 'TN': 24853, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1454 counts.
# Tag with the most false negative is:  ADJ with 729 counts.
# sentence:       ['A', 'fundamental', 'source', 'of', 'knowledge', 'in', 'the', 'world', 'today', 'is', 'the', 'book', 'found', 'in', 'our', 'libraries', '.']
# hidden s:       ['DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2947, 'FP': 238, 'TN': 21935, 'FN': 29}
# NOUN: {'TP': 6337, 'FP': 1455, 'TN': 18375, 'FN': 199}
# ADJ: {'TP': 1256, 'FP': 120, 'TN': 22925, 'FN': 730}
# VERB: {'TP': 2879, 'FP': 128, 'TN': 21335, 'FN': 697}
# ADP: {'TP': 3120, 'FP': 626, 'TN': 21758, 'FN': 33}
# .: {'TP': 3063, 'FP': 14, 'TN': 21848, 'FN': 0}
# ADV: {'TP': 746, 'FP': 18, 'TN': 23840, 'FN': 325}
# CONJ: {'TP': 708, 'FP': 3, 'TN': 24187, 'FN': 16}
# PRT: {'TP': 287, 'FP': 12, 'TN': 24256, 'FN': 368}
# PRON: {'TP': 604, 'FP': 2, 'TN': 24263, 'FN': 44}
# NUM: {'TP': 343, 'FP': 1, 'TN': 24429, 'FN': 139}
# X: {'TP': 4, 'FP': 0, 'TN': 24870, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1455 counts.
# Tag with the most false negative is:  ADJ with 730 counts.
# sentence:       ['Although', 'progress', 'has', 'been', 'made', 'in', "America's", 'system', 'of', 'libraries', 'it', 'still', 'falls', 'short', 'of', 'what', 'is', 'required', 'if', 'we', 'are', 'to', 'maintain', 'the', 'standards', 'that', 'are', 'needed', 'for', 'an', 'informed', 'America', '.']
# hidden s:       ['ADP', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'PRON', 'ADV', 'VERB', 'ADV', 'ADP', 'DET', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', '.']
# predictions:    ['ADP', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'PRON', 'ADV', 'DET', 'ADJ', 'ADP', 'DET', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'VERB', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', '.']
# DET: {'TP': 2950, 'FP': 239, 'TN': 21965, 'FN': 29}
# NOUN: {'TP': 6343, 'FP': 1455, 'TN': 18402, 'FN': 199}
# ADJ: {'TP': 1256, 'FP': 121, 'TN': 22958, 'FN': 730}
# VERB: {'TP': 2889, 'FP': 128, 'TN': 21357, 'FN': 698}
# ADP: {'TP': 3126, 'FP': 627, 'TN': 21785, 'FN': 33}
# .: {'TP': 3064, 'FP': 14, 'TN': 21880, 'FN': 0}
# ADV: {'TP': 747, 'FP': 18, 'TN': 23871, 'FN': 326}
# CONJ: {'TP': 708, 'FP': 3, 'TN': 24220, 'FN': 16}
# PRT: {'TP': 288, 'FP': 12, 'TN': 24288, 'FN': 368}
# PRON: {'TP': 606, 'FP': 2, 'TN': 24293, 'FN': 45}
# NUM: {'TP': 343, 'FP': 1, 'TN': 24462, 'FN': 139}
# X: {'TP': 4, 'FP': 0, 'TN': 24903, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1455 counts.
# Tag with the most false negative is:  ADJ with 730 counts.
# sentence:       ['The', 'problem', 'grows', 'in', 'intensity', 'each', 'year', 'as', "man's", 'knowledge', ',', 'and', 'his', 'capacity', 'to', 'translate', 'such', 'knowledge', 'to', 'the', 'written', 'word', ',', 'continue', 'to', 'expand', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'ADP', 'NOUN', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', 'PRT', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'VERB', 'NOUN', '.', 'VERB', 'PRT', 'VERB', '.']
# predictions:    ['DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'VERB', 'NOUN', '.', 'VERB', 'PRT', 'VERB', '.']
# DET: {'TP': 2954, 'FP': 240, 'TN': 21988, 'FN': 29}
# NOUN: {'TP': 6351, 'FP': 1456, 'TN': 18421, 'FN': 199}
# ADJ: {'TP': 1257, 'FP': 121, 'TN': 22984, 'FN': 730}
# VERB: {'TP': 2892, 'FP': 128, 'TN': 21379, 'FN': 700}
# ADP: {'TP': 3129, 'FP': 628, 'TN': 21809, 'FN': 33}
# .: {'TP': 3067, 'FP': 14, 'TN': 21904, 'FN': 0}
# ADV: {'TP': 747, 'FP': 18, 'TN': 23898, 'FN': 326}
# CONJ: {'TP': 709, 'FP': 3, 'TN': 24246, 'FN': 16}
# PRT: {'TP': 289, 'FP': 12, 'TN': 24313, 'FN': 369}
# PRON: {'TP': 606, 'FP': 2, 'TN': 24320, 'FN': 45}
# NUM: {'TP': 343, 'FP': 1, 'TN': 24489, 'FN': 139}
# X: {'TP': 4, 'FP': 0, 'TN': 24930, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1456 counts.
# Tag with the most false negative is:  ADJ with 730 counts.
# sentence:       ['The', 'inadequacy', 'of', 'our', 'library', 'system', 'will', 'become', 'critical', 'unless', 'we', 'act', 'vigorously', 'to', 'correct', 'this', 'condition', '.']
# hidden s:       ['DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADJ', 'ADP', 'PRON', 'VERB', 'ADV', 'PRT', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADJ', 'ADP', 'PRON', 'VERB', 'NOUN', 'ADP', 'VERB', 'DET', 'NOUN', '.']
# DET: {'TP': 2957, 'FP': 240, 'TN': 22003, 'FN': 29}
# NOUN: {'TP': 6355, 'FP': 1457, 'TN': 18435, 'FN': 199}
# ADJ: {'TP': 1258, 'FP': 121, 'TN': 23001, 'FN': 730}
# VERB: {'TP': 2896, 'FP': 128, 'TN': 21393, 'FN': 700}
# ADP: {'TP': 3131, 'FP': 629, 'TN': 21825, 'FN': 33}
# .: {'TP': 3068, 'FP': 14, 'TN': 21921, 'FN': 0}
# ADV: {'TP': 747, 'FP': 18, 'TN': 23915, 'FN': 327}
# CONJ: {'TP': 709, 'FP': 3, 'TN': 24264, 'FN': 16}
# PRT: {'TP': 289, 'FP': 12, 'TN': 24330, 'FN': 370}
# PRON: {'TP': 607, 'FP': 2, 'TN': 24337, 'FN': 45}
# NUM: {'TP': 343, 'FP': 1, 'TN': 24507, 'FN': 139}
# X: {'TP': 4, 'FP': 0, 'TN': 24948, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1457 counts.
# Tag with the most false negative is:  ADJ with 730 counts.
# sentence:       ['There', 'are', ',', 'for', 'example', ',', 'approximately', '25,000,000', 'people', 'in', 'this', 'country', 'with', 'no', 'public', 'library', 'service', 'and', 'about', '50,000,000', 'with', 'inadequate', 'service', '.']
# hidden s:       ['PRT', 'VERB', '.', 'ADP', 'NOUN', '.', 'ADV', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'CONJ', 'ADV', 'NUM', 'ADP', 'ADJ', 'NOUN', '.']
# predictions:    ['PRT', 'VERB', '.', 'ADP', 'NOUN', '.', 'ADV', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', 'CONJ', 'ADP', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.']
# DET: {'TP': 2959, 'FP': 240, 'TN': 22025, 'FN': 29}
# NOUN: {'TP': 6361, 'FP': 1459, 'TN': 18453, 'FN': 199}
# ADJ: {'TP': 1259, 'FP': 121, 'TN': 23023, 'FN': 731}
# VERB: {'TP': 2897, 'FP': 128, 'TN': 21416, 'FN': 700}
# ADP: {'TP': 3135, 'FP': 631, 'TN': 21845, 'FN': 33}
# .: {'TP': 3071, 'FP': 14, 'TN': 21942, 'FN': 0}
# ADV: {'TP': 748, 'FP': 18, 'TN': 23937, 'FN': 328}
# CONJ: {'TP': 710, 'FP': 3, 'TN': 24287, 'FN': 16}
# PRT: {'TP': 290, 'FP': 12, 'TN': 24353, 'FN': 370}
# PRON: {'TP': 607, 'FP': 2, 'TN': 24361, 'FN': 45}
# NUM: {'TP': 343, 'FP': 1, 'TN': 24529, 'FN': 141}
# X: {'TP': 4, 'FP': 0, 'TN': 24972, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1459 counts.
# Tag with the most false negative is:  ADJ with 731 counts.
# sentence:       ['In', 'college', 'libraries', ',', '57', 'per', 'cent', 'of', 'the', 'total', 'number', 'of', 'books', 'are', 'owned', 'by', '124', 'of', '1,509', 'institutions', 'surveyed', 'last', 'year', 'by', 'the', 'U.S.', 'Office', 'of', 'Education', '.']
# hidden s:       ['ADP', 'NOUN', 'NOUN', '.', 'NUM', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'ADP', 'NUM', 'ADP', 'NUM', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['ADP', 'NOUN', 'NOUN', '.', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.']
# DET: {'TP': 2961, 'FP': 241, 'TN': 22053, 'FN': 29}
# NOUN: {'TP': 6372, 'FP': 1461, 'TN': 18472, 'FN': 199}
# ADJ: {'TP': 1260, 'FP': 121, 'TN': 23052, 'FN': 731}
# VERB: {'TP': 2900, 'FP': 128, 'TN': 21443, 'FN': 700}
# ADP: {'TP': 3143, 'FP': 631, 'TN': 21867, 'FN': 33}
# .: {'TP': 3073, 'FP': 14, 'TN': 21970, 'FN': 0}
# ADV: {'TP': 748, 'FP': 18, 'TN': 23967, 'FN': 328}
# CONJ: {'TP': 710, 'FP': 3, 'TN': 24317, 'FN': 16}
# PRT: {'TP': 290, 'FP': 12, 'TN': 24383, 'FN': 370}
# PRON: {'TP': 607, 'FP': 2, 'TN': 24391, 'FN': 45}
# NUM: {'TP': 343, 'FP': 1, 'TN': 24556, 'FN': 144}
# X: {'TP': 4, 'FP': 0, 'TN': 25002, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1461 counts.
# Tag with the most false negative is:  ADJ with 731 counts.
# sentence:       ['And', 'over', '66', 'per', 'cent', 'of', 'the', 'elementary', 'schools', 'with', '150', 'or', 'more', 'pupils', 'do', 'not', 'have', 'any', 'library', 'at', 'all', '.']
# hidden s:       ['CONJ', 'PRT', 'NUM', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NUM', 'CONJ', 'ADJ', 'NOUN', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'PRT', '.']
# predictions:    ['CONJ', 'ADP', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NUM', 'CONJ', 'ADJ', 'NOUN', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'PRT', '.']
# DET: {'TP': 2963, 'FP': 241, 'TN': 22073, 'FN': 29}
# NOUN: {'TP': 6376, 'FP': 1462, 'TN': 18490, 'FN': 199}
# ADJ: {'TP': 1262, 'FP': 121, 'TN': 23072, 'FN': 731}
# VERB: {'TP': 2902, 'FP': 128, 'TN': 21463, 'FN': 700}
# ADP: {'TP': 3147, 'FP': 632, 'TN': 21885, 'FN': 33}
# .: {'TP': 3074, 'FP': 14, 'TN': 21991, 'FN': 0}
# ADV: {'TP': 749, 'FP': 18, 'TN': 23988, 'FN': 328}
# CONJ: {'TP': 712, 'FP': 3, 'TN': 24337, 'FN': 16}
# PRT: {'TP': 291, 'FP': 12, 'TN': 24403, 'FN': 371}
# PRON: {'TP': 607, 'FP': 2, 'TN': 24413, 'FN': 45}
# NUM: {'TP': 344, 'FP': 1, 'TN': 24576, 'FN': 145}
# X: {'TP': 4, 'FP': 0, 'TN': 25024, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1462 counts.
# Tag with the most false negative is:  ADJ with 731 counts.
# sentence:       ['In', 'every', 'aspect', 'of', 'service', '--', 'to', 'the', 'public', ',', 'to', 'children', 'in', 'schools', ',', 'to', 'colleges', 'and', 'universities', '--', 'the', 'library', 'of', 'today', 'is', 'failing', 'to', 'render', 'vitally', 'needed', 'services', '.']
# hidden s:       ['ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'NOUN', 'CONJ', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'PRT', 'VERB', 'ADV', 'VERB', 'NOUN', '.']
# predictions:    ['ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'NOUN', 'CONJ', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'VERB', 'NOUN', '.']
# DET: {'TP': 2966, 'FP': 242, 'TN': 22102, 'FN': 29}
# NOUN: {'TP': 6386, 'FP': 1463, 'TN': 18512, 'FN': 199}
# ADJ: {'TP': 1262, 'FP': 121, 'TN': 23104, 'FN': 731}
# VERB: {'TP': 2905, 'FP': 128, 'TN': 21491, 'FN': 701}
# ADP: {'TP': 3154, 'FP': 633, 'TN': 21910, 'FN': 33}
# .: {'TP': 3079, 'FP': 14, 'TN': 22018, 'FN': 0}
# ADV: {'TP': 749, 'FP': 18, 'TN': 24019, 'FN': 329}
# CONJ: {'TP': 713, 'FP': 3, 'TN': 24368, 'FN': 16}
# PRT: {'TP': 291, 'FP': 12, 'TN': 24434, 'FN': 372}
# PRON: {'TP': 607, 'FP': 2, 'TN': 24445, 'FN': 45}
# NUM: {'TP': 344, 'FP': 1, 'TN': 24608, 'FN': 145}
# X: {'TP': 4, 'FP': 0, 'TN': 25056, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1463 counts.
# Tag with the most false negative is:  ADJ with 731 counts.
# sentence:       ['Only', 'public', 'understanding', 'and', 'support', 'can', 'provide', 'that', 'service', '.']
# hidden s:       ['ADJ', 'ADJ', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['ADJ', 'NOUN', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', '.']
# DET: {'TP': 2966, 'FP': 242, 'TN': 22111, 'FN': 30}
# NOUN: {'TP': 6389, 'FP': 1464, 'TN': 18519, 'FN': 199}
# ADJ: {'TP': 1263, 'FP': 121, 'TN': 23112, 'FN': 732}
# VERB: {'TP': 2907, 'FP': 128, 'TN': 21499, 'FN': 701}
# ADP: {'TP': 3154, 'FP': 634, 'TN': 21920, 'FN': 33}
# .: {'TP': 3080, 'FP': 14, 'TN': 22027, 'FN': 0}
# ADV: {'TP': 749, 'FP': 18, 'TN': 24029, 'FN': 329}
# CONJ: {'TP': 714, 'FP': 3, 'TN': 24377, 'FN': 16}
# PRT: {'TP': 291, 'FP': 12, 'TN': 24444, 'FN': 372}
# PRON: {'TP': 607, 'FP': 2, 'TN': 24455, 'FN': 45}
# NUM: {'TP': 344, 'FP': 1, 'TN': 24618, 'FN': 145}
# X: {'TP': 4, 'FP': 0, 'TN': 25066, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1464 counts.
# Tag with the most false negative is:  ADJ with 732 counts.
# sentence:       ['This', 'is', 'one', 'of', 'the', 'main', 'reasons', 'for', 'National', 'Library', 'Week', ',', 'April', '16-22', ',', 'and', 'for', 'its', 'theme', ':', '``', 'For', 'a', 'richer', ',', 'fuller', 'life', ',', 'read', "''", '!', '!']
# hidden s:       ['DET', 'VERB', 'NUM', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', '.', 'NOUN', 'NUM', '.', 'CONJ', 'ADP', 'DET', 'NOUN', '.', '.', 'ADP', 'DET', 'ADJ', '.', 'ADJ', 'NOUN', '.', 'VERB', '.', '.', '.']
# predictions:    ['DET', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'CONJ', 'ADP', 'DET', 'NOUN', '.', '.', 'ADP', 'DET', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'VERB', '.', '.', '.']
# DET: {'TP': 2970, 'FP': 242, 'TN': 22139, 'FN': 30}
# NOUN: {'TP': 6395, 'FP': 1469, 'TN': 18545, 'FN': 199}
# ADJ: {'TP': 1264, 'FP': 121, 'TN': 23140, 'FN': 735}
# VERB: {'TP': 2909, 'FP': 128, 'TN': 21529, 'FN': 701}
# ADP: {'TP': 3158, 'FP': 634, 'TN': 21948, 'FN': 33}
# .: {'TP': 3089, 'FP': 14, 'TN': 22050, 'FN': 0}
# ADV: {'TP': 749, 'FP': 18, 'TN': 24061, 'FN': 329}
# CONJ: {'TP': 715, 'FP': 3, 'TN': 24408, 'FN': 16}
# PRT: {'TP': 291, 'FP': 12, 'TN': 24476, 'FN': 372}
# PRON: {'TP': 607, 'FP': 2, 'TN': 24487, 'FN': 45}
# NUM: {'TP': 344, 'FP': 1, 'TN': 24648, 'FN': 147}
# X: {'TP': 4, 'FP': 0, 'TN': 25098, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1469 counts.
# Tag with the most false negative is:  ADJ with 735 counts.
#
# model got 22495 samples correct out of 25139
# accuracy: 0.8948247742551414
